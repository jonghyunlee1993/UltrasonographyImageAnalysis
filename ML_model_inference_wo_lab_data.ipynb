# %% [markdown]
# # Fibroscan

# %%
import pandas as pd
from pycaret.regression import *

df = pd.read_csv("data/fibroscan_predict_df.csv")
df = df.loc[:, ["ID", "kPa_fib", "v1", "v2", "v3", "v4", "v5"]]
df.kPa_fib = df.kPa_fib.map(lambda x: 16 if x > 16 else x)
df.kPa_fib = df.kPa_fib.map(lambda x: 4 if x < 4 else x)
reg = setup(data=df, target='kPa_fib', fold=5, session_id=42)
# Out:
# <style type="text/css">
# #T_61e19_row3_col1, #T_61e19_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_61e19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61e19_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_61e19_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61e19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61e19_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_61e19_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_61e19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61e19_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_61e19_row1_col1" class="data row1 col1" >kPa_fib</td>
#     </tr>
#     <tr>
#       <th id="T_61e19_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lr = create_model('lr')
tuned_xgb = tune_model(
    lr, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_cb50a_row5_col0, #T_cb50a_row5_col1, #T_cb50a_row5_col2, #T_cb50a_row5_col3, #T_cb50a_row5_col4, #T_cb50a_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cb50a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb50a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cb50a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cb50a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cb50a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cb50a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cb50a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
dt = create_model('dt')
tuned_dt = tune_model(
    dt, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_e269a_row5_col0, #T_e269a_row5_col1, #T_e269a_row5_col2, #T_e269a_row5_col3, #T_e269a_row5_col4, #T_e269a_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e269a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e269a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e269a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e269a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e269a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e269a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e269a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
lightgbm = create_model('lightgbm')
tuned_lightgbm = tune_model(
    lightgbm, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_1b4c3_row5_col0, #T_1b4c3_row5_col1, #T_1b4c3_row5_col2, #T_1b4c3_row5_col3, #T_1b4c3_row5_col4, #T_1b4c3_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1b4c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b4c3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1b4c3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1b4c3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1b4c3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1b4c3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1b4c3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# # MRE

# %%
import pandas as pd
from pycaret.regression import *

df = pd.read_csv("data/mre_predict_df.csv")
df = df.loc[:, ["ID", "kPa_mre", "v1", "v2", "v3", "v4", "v5"]]
df.kPa_mre = df.kPa_mre.map(lambda x: 7 if x > 7 else x)
df.kPa_mre = df.kPa_mre.map(lambda x: 2 if x < 2 else x)
reg = setup(data=df, target='kPa_mre', fold=5, session_id=42)
# Out:
# <style type="text/css">
# #T_d3506_row3_col1, #T_d3506_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d3506">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3506_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d3506_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3506_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3506_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d3506_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_d3506_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3506_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d3506_row1_col1" class="data row1 col1" >kPa_mre</td>
#     </tr>
#     <tr>
#       <th id="T_d3506_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lr = create_model('lr')
tuned_xgb = tune_model(
    lr, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_ae0d1_row5_col0, #T_ae0d1_row5_col1, #T_ae0d1_row5_col2, #T_ae0d1_row5_col3, #T_ae0d1_row5_col4, #T_ae0d1_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ae0d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae0d1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ae0d1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ae0d1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ae0d1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ae0d1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ae0d1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
dt = create_model('dt')
tuned_dt = tune_model(
    dt, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_7206c_row5_col0, #T_7206c_row5_col1, #T_7206c_row5_col2, #T_7206c_row5_col3, #T_7206c_row5_col4, #T_7206c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7206c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7206c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7206c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7206c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7206c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7206c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7206c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
lightgbm = create_model('lightgbm')
tuned_lightgbm = tune_model(
    lightgbm, optimize='RMSE', n_iter=100, 
    search_library='optuna', choose_better=True)
# Out:
# <style type="text/css">
# #T_7fa8f_row5_col0, #T_7fa8f_row5_col1, #T_7fa8f_row5_col2, #T_7fa8f_row5_col3, #T_7fa8f_row5_col4, #T_7fa8f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7fa8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fa8f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7fa8f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7fa8f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7fa8f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7fa8f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7fa8f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
